# %% [markdown]
# # CAN Workshop- LFADS demo in pytorch

# %% [markdown]
# ## Import necessary modules

# %%
# %matplotlib inline

import torch
import torchvision
np = torch._np
import matplotlib.pyplot as plt

import os
import yaml

from lfads_sim import LFADS_Net
from utils import read_data, load_parameters, save_parameters
import scipy.io
# plt.style.use('dark_background')

# %%
# Select device to train LFADS on
device = 'cuda' if torch.cuda.is_available() else 'cpu'; print('Using device: %s'%device)
# Out:
# Using device: cuda

# %% [markdown]
# ## Load or Generate Data

# %%
all_time =3000
Time = 20
neuron_num = 30
datax = scipy.io.loadmat("spike30_sim_3000.mat")
y_data = datax["spike30_sim_3000"][:,:all_time]
traj = scipy.io.loadmat("trj30_sim_3000.mat")
traj = traj["trj30_sim_3000"][:,:all_time]
NRep=int(all_time/Time)
output = np.zeros((NRep,Time,neuron_num))
print(y_data.shape)
for i in range(NRep):
    output[i,:,:] = y_data[Time*i:Time*(i+1),:]
output = output.astype('float32')
output = torch.Tensor(output).to(device)
print(output.shape)
output_valid = output.detach().clone()
# Out:
# (3000, 30)
# torch.Size([150, 20, 30])

# %% [markdown]
# ## View example Ground Truth Firing Rates

# %%
train_ds      = torch.utils.data.TensorDataset(output)
valid_ds      = torch.utils.data.TensorDataset(output)
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(traj[:,0],traj[:,1])
plt.figure(figsize=(4, 4))
ax1 = plt.subplot(311)
ax1.plot(traj[:, 0], lw=4, color='k')

ax2 = plt.subplot(312, sharex=ax1)
ax2.plot(traj[:, 1], lw=4, color='k')    

# Z score output:
output=output.reshape(Time*NRep,neuron_num)
from scipy import stats
output = stats.zscore(output,axis=0)
output = output.reshape(NRep,Time,neuron_num)
print(output[0].shape)
plt.figure(figsize = (12,12))
plt.imshow(y_data.T, cmap=plt.cm.plasma,aspect='auto')
plt.xlabel('Time (s)')
plt.ylabel('Cell #')
plt.colorbar(orientation='horizontal', label='Firing Rate (Hz)')
# Out:
# (20, 30)

# %%
for i in range(neuron_num):
    fig, ax = plt.subplots()
    mappable = ax.scatter(traj[:,0], traj[:,1], c=y_data[:,i] ,cmap='coolwarm',vmin=0,vmax=8)
    fig.colorbar(mappable)
    plt.show()
fig.savefig("img.png")

# %% [markdown]
# ## LFADS Schema
# <img src='lfads_schema.png' width=800 align=left>

# %% [markdown]
# ## Load model hyperparameters

# %%
hyperparams = load_parameters('./parameters.yaml')
save_parameters(hyperparams)
hyperparams
# Out:
# {'dataset_name': 'chaotic_rnn',
#  'run_name': 'demo',
#  'g_dim': 50,
#  'u_dim': 1,
#  'factors_dim': 2,
#  'g0_encoder_dim': 50,
#  'c_encoder_dim': 128,
#  'controller_dim': 128,
#  'g0_prior_kappa': 0.1,
#  'u_prior_kappa': 0.1,
#  'keep_prob': 0.95,
#  'clip_val': 5.0,
#  'max_norm': 200,
#  'learning_rate': 0.01,
#  'learning_rate_min': 1e-05,
#  'learning_rate_decay': 0.95,
#  'scheduler_on': True,
#  'scheduler_patience': 6,
#  'scheduler_cooldown': 6,
#  'kl_weight_schedule_start': 0,
#  'kl_weight_schedule_dur': 2000,
#  'l2_weight_schedule_start': 0,
#  'l2_weight_schedule_dur': 2000,
#  'epsilon': 0.1,
#  'betas': (0.9, 0.99),
#  'l2_gen_scale': 2000,
#  'l2_con_scale': 0}

# %% [markdown]
# ## Instantiate LFADS model

# %%
model = LFADS_Net(inputs_dim = neuron_num, T = Time, dt = 1, device=device,
                 model_hyperparams=hyperparams).to(device)
# Out:
# Random seed: 5519

# %% [markdown]
# #### Pick up where you left off (if you have a recent save)

# %%
# model.load_checkpoint('recent')
batch_size = 1
"""tt = np.empty((3000,2))
for k in range(10):
    t = model.infer_trj(output_valid[batch_size *k:batch_size *(k+1),:])
    #print(t[90].shape)
    for i in range(batch_size):
        for j in range(100):
            tt[k*100*i+j,:]=t[j][i].to('cpu').detach().numpy().copy()
plt.figure()
plt.plot(tt)"""
# Out:
# "tt = np.empty((3000,2))\nfor k in range(10):\n    t = model.infer_trj(output_valid[batch_size *k:batch_size *(k+1),:])\n    #print(t[90].shape)\n    for i in range(batch_size):\n        for j in range(100):\n            tt[k*100*i+j,:]=t[j][i].to('cpu').detach().numpy().copy()\nplt.figure()\nplt.plot(tt)"

# %% [markdown]
# ## Fit model
#
# Rule of thumb: You can usually see good fit after 200 epochs (~30 mins runtime on Thinkpad GPU, ~2.5 hours on CPU), but to see good inference of perturbation timings need to run for about 800 epochs (~2 hours on Thinkpad GPU).

# %%
model.fit(train_ds, valid_ds, max_epochs=180, batch_size=batch_size , use_tensorboard=False,
          train_truth=train_ds, valid_truth=valid_ds)
# Out:
# Beginning training...
# Epoch:    1, Step:   150, training loss: 538.823
# Epoch:    2, Step:   300, training loss: 361.885
# Epoch:    3, Step:   450, training loss: 330.037
# Epoch:    4, Step:   600, training loss: 311.170
# Epoch:    5, Step:   750, training loss: 313.468
# Epoch:    6, Step:   900, training loss: 304.093
# Epoch:    7, Step:  1050, training loss: 308.311
# Epoch:    8, Step:  1200, training loss: 294.543
# Epoch:    9, Step:  1350, training loss: 302.310
# Epoch:   10, Step:  1500, training loss: 317.255
# Learning rate decreased to 0.00950000
# Epoch:   11, Step:  1650, training loss: 300.342
# Epoch:   12, Step:  1800, training loss: 298.381
# Epoch:   13, Step:  1950, training loss: 298.730
# Epoch:   14, Step:  2100, training loss: 289.819
# Epoch:   15, Step:  2250, training loss: 296.763
# Epoch:   16, Step:  2400, training loss: 292.010
# Epoch:   17, Step:  2550, training loss: 304.788
# Learning rate decreased to 0.00902500
# Epoch:   18, Step:  2700, training loss: 292.716
# Epoch:   19, Step:  2850, training loss: 278.315
# Epoch:   20, Step:  3000, training loss: 279.974
# Epoch:   21, Step:  3150, training loss: 286.105
# Epoch:   22, Step:  3300, training loss: 275.630
# Epoch:   23, Step:  3450, training loss: 274.850
# Epoch:   24, Step:  3600, training loss: 271.531
# Epoch:   25, Step:  3750, training loss: 276.262
# Epoch:   26, Step:  3900, training loss: 279.608
# Epoch:   27, Step:  4050, training loss: 279.044
# Epoch:   28, Step:  4200, training loss: 277.183
# Epoch:   29, Step:  4350, training loss: 270.190
# Epoch:   30, Step:  4500, training loss: 273.151
# Epoch:   31, Step:  4650, training loss: 269.001
# Epoch:   32, Step:  4800, training loss: 272.552
# Epoch:   33, Step:  4950, training loss: 270.673
# Epoch:   34, Step:  5100, training loss: 266.970
# Epoch:   35, Step:  5250, training loss: 273.453
# Learning rate decreased to 0.00857375
# Epoch:   36, Step:  5400, training loss: 266.305
# Epoch:   37, Step:  5550, training loss: 263.852
# Epoch:   38, Step:  5700, training loss: 258.948
# Epoch:   39, Step:  5850, training loss: 259.439
# Epoch:   40, Step:  6000, training loss: 271.902
# Epoch:   41, Step:  6150, training loss: 264.643
# Epoch:   42, Step:  6300, training loss: 258.632
# Epoch:   43, Step:  6450, training loss: 269.642
# Epoch:   44, Step:  6600, training loss: 260.258
# Epoch:   45, Step:  6750, training loss: 260.820
# Epoch:   46, Step:  6900, training loss: 255.675
# Epoch:   47, Step:  7050, training loss: 257.872
# Epoch:   48, Step:  7200, training loss: 260.448
# Epoch:   49, Step:  7350, training loss: 255.938
# Epoch:   50, Step:  7500, training loss: 260.771
# Epoch:   51, Step:  7650, training loss: 254.204
# Epoch:   52, Step:  7800, training loss: 257.961
# Epoch:   53, Step:  7950, training loss: 255.180
# Epoch:   54, Step:  8100, training loss: 252.560
# Epoch:   55, Step:  8250, training loss: 259.224
# Epoch:   56, Step:  8400, training loss: 262.769
# Learning rate decreased to 0.00814506
# Epoch:   57, Step:  8550, training loss: 248.788
# Epoch:   58, Step:  8700, training loss: 247.835
# Epoch:   59, Step:  8850, training loss: 257.867
# Epoch:   60, Step:  9000, training loss: 248.235
# Epoch:   61, Step:  9150, training loss: 256.897
# Epoch:   62, Step:  9300, training loss: 258.495
# Epoch:   63, Step:  9450, training loss: 252.995
# Epoch:   64, Step:  9600, training loss: 249.998
# Epoch:   65, Step:  9750, training loss: 253.012
# Epoch:   66, Step:  9900, training loss: 248.187
# Epoch:   67, Step: 10050, training loss: 258.873
# Learning rate decreased to 0.00773781
# Epoch:   68, Step: 10200, training loss: 247.098
# Epoch:   69, Step: 10350, training loss: 247.253
# Epoch:   70, Step: 10500, training loss: 252.632
# Epoch:   71, Step: 10650, training loss: 255.583
# Epoch:   72, Step: 10800, training loss: 251.110
# Epoch:   73, Step: 10950, training loss: 242.810
# Epoch:   74, Step: 11100, training loss: 245.849
# Epoch:   75, Step: 11250, training loss: 268.524
# Learning rate decreased to 0.00735092
# Epoch:   76, Step: 11400, training loss: 252.433
# Epoch:   77, Step: 11550, training loss: 253.070
# Epoch:   78, Step: 11700, training loss: 250.441
# Epoch:   79, Step: 11850, training loss: 254.445
# Epoch:   80, Step: 12000, training loss: 247.783
# Epoch:   81, Step: 12150, training loss: 244.367
# Epoch:   82, Step: 12300, training loss: 240.664
# Epoch:   83, Step: 12450, training loss: 248.519
# Epoch:   84, Step: 12600, training loss: 242.425
# Epoch:   85, Step: 12750, training loss: 257.505
# Learning rate decreased to 0.00698337
# Epoch:   86, Step: 12900, training loss: 257.736
# Epoch:   87, Step: 13050, training loss: 245.663
# Epoch:   88, Step: 13200, training loss: 261.984
# Epoch:   89, Step: 13350, training loss: 246.645
# Epoch:   90, Step: 13500, training loss: 247.175
# Epoch:   91, Step: 13650, training loss: 244.195
# Epoch:   92, Step: 13800, training loss: 241.628
# Epoch:   93, Step: 13950, training loss: 241.165
# Epoch:   94, Step: 14100, training loss: 239.037
# Epoch:   95, Step: 14250, training loss: 248.893
# Learning rate decreased to 0.00663420
# Epoch:   96, Step: 14400, training loss: 246.461
# Epoch:   97, Step: 14550, training loss: 247.634
# Epoch:   98, Step: 14700, training loss: 255.760
# Epoch:   99, Step: 14850, training loss: 262.261
# Epoch:  100, Step: 15000, training loss: 253.732
# Epoch:  101, Step: 15150, training loss: 237.970
# Epoch:  102, Step: 15300, training loss: 245.183
# Epoch:  103, Step: 15450, training loss: 239.258
# Epoch:  104, Step: 15600, training loss: 255.770
# Epoch:  105, Step: 15750, training loss: 256.360
# Epoch:  106, Step: 15900, training loss: 244.443
# Epoch:  107, Step: 16050, training loss: 244.778
# Epoch:  108, Step: 16200, training loss: 248.342
# Epoch:  109, Step: 16350, training loss: 242.601
# Epoch:  110, Step: 16500, training loss: 237.983
# Epoch:  111, Step: 16650, training loss: 246.186
# Epoch:  112, Step: 16800, training loss: 248.899
# Learning rate decreased to 0.00630249
# Epoch:  113, Step: 16950, training loss: 250.784
# Epoch:  114, Step: 17100, training loss: 248.625
# Epoch:  115, Step: 17250, training loss: 239.993
# Epoch:  116, Step: 17400, training loss: 242.228
# Epoch:  117, Step: 17550, training loss: 234.967
# Epoch:  118, Step: 17700, training loss: 236.013
# Epoch:  119, Step: 17850, training loss: 244.449
# Epoch:  120, Step: 18000, training loss: 241.765
# Epoch:  121, Step: 18150, training loss: 240.705
# Epoch:  122, Step: 18300, training loss: 237.914
# Epoch:  123, Step: 18450, training loss: 237.853
# Epoch:  124, Step: 18600, training loss: 249.324
# Learning rate decreased to 0.00598737
# Epoch:  125, Step: 18750, training loss: 231.997
# Epoch:  126, Step: 18900, training loss: 234.072
# Epoch:  127, Step: 19050, training loss: 229.030
# Epoch:  128, Step: 19200, training loss: 239.076
# Epoch:  129, Step: 19350, training loss: 236.867
# Epoch:  130, Step: 19500, training loss: 238.009
# Epoch:  131, Step: 19650, training loss: 240.233
# Learning rate decreased to 0.00568800
# Epoch:  132, Step: 19800, training loss: 244.809
# Epoch:  133, Step: 19950, training loss: 242.993
# Epoch:  134, Step: 20100, training loss: 242.348
# Epoch:  135, Step: 20250, training loss: 228.268
# Epoch:  136, Step: 20400, training loss: 236.470
# Epoch:  137, Step: 20550, training loss: 243.730
# Epoch:  138, Step: 20700, training loss: 229.733
# Epoch:  139, Step: 20850, training loss: 232.803
# Epoch:  140, Step: 21000, training loss: 232.615
# Epoch:  141, Step: 21150, training loss: 230.840
# Epoch:  142, Step: 21300, training loss: 233.486
# Epoch:  143, Step: 21450, training loss: 232.314
# Epoch:  144, Step: 21600, training loss: 236.803
# Learning rate decreased to 0.00540360
# Epoch:  145, Step: 21750, training loss: 226.875
# Epoch:  146, Step: 21900, training loss: 242.999
# Epoch:  147, Step: 22050, training loss: 232.494
# Epoch:  148, Step: 22200, training loss: 233.459
# Epoch:  149, Step: 22350, training loss: 233.476
# Epoch:  150, Step: 22500, training loss: 238.686
# Epoch:  151, Step: 22650, training loss: 228.253
# Epoch:  152, Step: 22800, training loss: 235.071
# Epoch:  153, Step: 22950, training loss: 230.588
# Epoch:  154, Step: 23100, training loss: 237.156
# Epoch:  155, Step: 23250, training loss: 229.393
# Epoch:  156, Step: 23400, training loss: 232.250
# Epoch:  157, Step: 23550, training loss: 235.416
# Epoch:  158, Step: 23700, training loss: 236.764
# Epoch:  159, Step: 23850, training loss: 234.749
# Epoch:  160, Step: 24000, training loss: 234.168
# Epoch:  161, Step: 24150, training loss: 230.764
# Epoch:  162, Step: 24300, training loss: 237.136
# Learning rate decreased to 0.00513342
# Epoch:  163, Step: 24450, training loss: 226.962
# Epoch:  164, Step: 24600, training loss: 235.663
# Epoch:  165, Step: 24750, training loss: 230.040
# Epoch:  166, Step: 24900, training loss: 241.174
# Epoch:  167, Step: 25050, training loss: 225.809
# Epoch:  168, Step: 25200, training loss: 225.009
# Epoch:  169, Step: 25350, training loss: 232.684
# Epoch:  170, Step: 25500, training loss: 226.660
# Epoch:  171, Step: 25650, training loss: 225.091
# Epoch:  172, Step: 25800, training loss: 229.591
# Epoch:  173, Step: 25950, training loss: 235.723
# Learning rate decreased to 0.00487675
# Epoch:  174, Step: 26100, training loss: 230.413
# Epoch:  175, Step: 26250, training loss: 224.596
# Epoch:  176, Step: 26400, training loss: 232.069
# Epoch:  177, Step: 26550, training loss: 227.584
# Epoch:  178, Step: 26700, training loss: 236.831
# Epoch:  179, Step: 26850, training loss: 227.081
# Epoch:  180, Step: 27000, training loss: 226.576
# ...training complete.

# %% [markdown]
# ## Load checkpoint with lowest validation error

# %%
model.load_checkpoint('best')

# %% [markdown]
# ## Plot results summary

# %%
print(output_valid.shape)
#model.plot_factors()
tt = np.zeros((all_time,2))
gg = int(NRep/batch_size)
for k in range(gg):
    t = model.infer_factors(output_valid[batch_size *k:batch_size *(k+1),:])
    #print(t)
    for i in range(batch_size):
        for j in range(Time):
            tt[(i+batch_size*k)*Time+j,:]=t[i][j].to('cpu').detach().numpy().copy()
plt.figure()
plt.plot(tt)
# Out:
# torch.Size([150, 20, 30])
# [<matplotlib.lines.Line2D at 0x1fab22568d0>,
#  <matplotlib.lines.Line2D at 0x1fab2256a20>]

# %%
import funs
qz_mean_est = tt
#plt.plot(qz_mean_est[:,0])
qz_est_norm = qz_mean_est#np.stack(qz_mean_est)/np.linalg.norm(np.stack(qz_mean_est))
#plt.plot(qz_est_norm[:,0],qz_est_norm[:,1])
z_true_c = traj# - x_test.mean(axis=0)
z_true_norm = z_true_c#/np.linalg.norm(z_true_c)

R = funs.compute_optimal_rotation(np.stack(qz_est_norm), z_true_norm, scale=True)
qz_est_norm_R = np.stack(qz_est_norm).dot(R)

from scipy import signal
qz_est_norm_R[:,0] = signal.savgol_filter(qz_est_norm_R[:,0], 51, 5)
qz_est_norm_R[:,1] = signal.savgol_filter(qz_est_norm_R[:,1],51, 5)
plt.figure(figsize=(14,8))
plt.subplot(211)
plt_post = plt.plot(qz_est_norm_R[:,0],'r', linewidth = 3, label = 'posterior mean')
plt_true = plt.plot(z_true_norm[:,0], 'k', linewidth = 3, label = '\"true\" mean')
plt.subplot(212)
plt_post = plt.plot(qz_est_norm_R[:,1],'r', linewidth = 3, label = 'posterior mean')
plt_true = plt.plot(z_true_norm[:,1], 'k', linewidth = 3, label = '\"true\" mean')

fig = plt.figure(figsize=(5,5))
plt.plot(z_true_norm[:,0], z_true_norm[:,1], lw=2, color = 'k')
plt.plot(qz_est_norm_R[:,0], qz_est_norm_R[:,1], lw=2, color = 'r')
