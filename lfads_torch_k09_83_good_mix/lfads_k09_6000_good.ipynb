# %% [markdown]
# # CAN Workshop- LFADS demo in pytorch

# %% [markdown]
# ## Import necessary modules

# %%
# %matplotlib inline

import torch
import torchvision
np = torch._np
import matplotlib.pyplot as plt

import os
import yaml

from lfads import LFADS_Net
from utils import read_data, load_parameters, save_parameters
import scipy.io
# plt.style.use('dark_background')

# %%
# Select device to train LFADS on
device = 'cuda' if torch.cuda.is_available() else 'cpu'; print('Using device: %s'%device)
# Out:
# Using device: cuda

# %% [markdown]
# ## Load or Generate Data

# %%
all_time =3000
Time = 10
neuron_num = 85
datax = scipy.io.loadmat("spike85_k09_6000.mat")
y_data = datax["spike85_k09_6000"][:,:all_time].T
traj = scipy.io.loadmat("trj85_k09_6000.mat")
traj = traj["trj85_k09_6000"][:,:all_time].T
NRep=int(all_time/Time)
output = np.zeros((NRep,Time,neuron_num))
print(y_data.shape)
for i in range(NRep):
    output[i,:,:] = y_data[Time*i:Time*(i+1),:]
output = output.astype('float32')
output = torch.Tensor(output).to(device)
print(output.shape)
output_valid = output.detach().clone()
# Out:
# (3000, 85)
# torch.Size([300, 10, 85])

# %% [markdown]
# ## View example Ground Truth Firing Rates

# %%
train_ds      = torch.utils.data.TensorDataset(output)
valid_ds      = torch.utils.data.TensorDataset(output)
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(traj[:,0],traj[:,1])
plt.figure(figsize=(4, 4))
ax1 = plt.subplot(311)
ax1.plot(traj[:, 0], lw=4, color='k')

ax2 = plt.subplot(312, sharex=ax1)
ax2.plot(traj[:, 1], lw=4, color='k')    

# Z score output:
output=output.reshape(Time*NRep,neuron_num)
from scipy import stats
output = stats.zscore(output,axis=0)
output = output.reshape(NRep,Time,neuron_num)
print(output[0].shape)
plt.figure(figsize = (12,12))
plt.imshow(y_data.T, cmap=plt.cm.plasma,aspect='auto')
plt.xlabel('Time (s)')
plt.ylabel('Cell #')
plt.colorbar(orientation='horizontal', label='Firing Rate (Hz)')
# Out:
# (10, 85)

# %% [markdown]
# ## LFADS Schema
# <img src='lfads_schema.png' width=800 align=left>

# %% [markdown]
# ## Load model hyperparameters

# %%
hyperparams = load_parameters('./parameters.yaml')
save_parameters(hyperparams)
hyperparams
# Out:
# {'dataset_name': 'chaotic_rnn',
#  'run_name': 'demo',
#  'g_dim': 50,
#  'u_dim': 1,
#  'factors_dim': 2,
#  'g0_encoder_dim': 200,
#  'c_encoder_dim': 128,
#  'controller_dim': 128,
#  'g0_prior_kappa': 0.1,
#  'u_prior_kappa': 0.1,
#  'keep_prob': 0.95,
#  'clip_val': 5.0,
#  'max_norm': 200,
#  'learning_rate': 0.01,
#  'learning_rate_min': 1e-05,
#  'learning_rate_decay': 0.95,
#  'scheduler_on': True,
#  'scheduler_patience': 6,
#  'scheduler_cooldown': 6,
#  'kl_weight_schedule_start': 0,
#  'kl_weight_schedule_dur': 2000,
#  'l2_weight_schedule_start': 0,
#  'l2_weight_schedule_dur': 2000,
#  'epsilon': 0.1,
#  'betas': (0.9, 0.99),
#  'l2_gen_scale': 2000,
#  'l2_con_scale': 0}

# %% [markdown]
# ## Instantiate LFADS model

# %%
model = LFADS_Net(inputs_dim = neuron_num, T = Time, dt = 1, device=device,
                 model_hyperparams=hyperparams).to(device)
# Out:
# Random seed: 4134

# %% [markdown]
# #### Pick up where you left off (if you have a recent save)

# %%
# model.load_checkpoint('recent')
batch_size = 1
"""tt = np.empty((3000,2))
for k in range(10):
    t = model.infer_trj(output_valid[batch_size *k:batch_size *(k+1),:])
    #print(t[90].shape)
    for i in range(batch_size):
        for j in range(100):
            tt[k*100*i+j,:]=t[j][i].to('cpu').detach().numpy().copy()
plt.figure()
plt.plot(tt)"""
# Out:
# "tt = np.empty((3000,2))\nfor k in range(10):\n    t = model.infer_trj(output_valid[batch_size *k:batch_size *(k+1),:])\n    #print(t[90].shape)\n    for i in range(batch_size):\n        for j in range(100):\n            tt[k*100*i+j,:]=t[j][i].to('cpu').detach().numpy().copy()\nplt.figure()\nplt.plot(tt)"

# %% [markdown]
# ## Fit model
#
# Rule of thumb: You can usually see good fit after 200 epochs (~30 mins runtime on Thinkpad GPU, ~2.5 hours on CPU), but to see good inference of perturbation timings need to run for about 800 epochs (~2 hours on Thinkpad GPU).

# %%
model.fit(train_ds, valid_ds, max_epochs=150, batch_size=batch_size , use_tensorboard=False,
          train_truth=train_ds, valid_truth=valid_ds)
# Out:
# Beginning training...
# Epoch:    1, Step:   300, training loss: 985.455, validation loss: 981.716
# Epoch:    2, Step:   600, training loss: 934.526, validation loss: 964.660
# Epoch:    3, Step:   900, training loss: 933.796, validation loss: 939.884
# Epoch:    4, Step:  1200, training loss: 926.319, validation loss: 928.688
# Epoch:    5, Step:  1500, training loss: 926.334, validation loss: 917.948
# Epoch:    6, Step:  1800, training loss: 920.186, validation loss: 914.257
# Epoch:    7, Step:  2100, training loss: 919.114, validation loss: 913.868
# Epoch:    8, Step:  2400, training loss: 919.670, validation loss: 912.910
# Epoch:    9, Step:  2700, training loss: 914.414, validation loss: 904.395
# Epoch:   10, Step:  3000, training loss: 910.010, validation loss: 898.490
# Epoch:   11, Step:  3300, training loss: 899.193, validation loss: 891.556
# Epoch:   12, Step:  3600, training loss: 889.076, validation loss: 875.648
# Epoch:   13, Step:  3900, training loss: 877.986, validation loss: 869.205
# Epoch:   14, Step:  4200, training loss: 873.644, validation loss: 865.962
# Epoch:   15, Step:  4500, training loss: 872.047, validation loss: 862.131
# Epoch:   16, Step:  4800, training loss: 869.057, validation loss: 865.624
# Epoch:   17, Step:  5100, training loss: 867.305, validation loss: 863.449
# Epoch:   18, Step:  5400, training loss: 865.937, validation loss: 860.862
# Epoch:   19, Step:  5700, training loss: 861.335, validation loss: 853.367
# Epoch:   20, Step:  6000, training loss: 863.976, validation loss: 853.644
# Epoch:   21, Step:  6300, training loss: 859.224, validation loss: 844.828
# Epoch:   22, Step:  6600, training loss: 854.725, validation loss: 847.826
# Epoch:   23, Step:  6900, training loss: 855.588, validation loss: 844.780
# Epoch:   24, Step:  7200, training loss: 852.524, validation loss: 855.390
# Epoch:   25, Step:  7500, training loss: 853.936, validation loss: 845.627
# Epoch:   26, Step:  7800, training loss: 854.601, validation loss: 846.966
# Epoch:   27, Step:  8100, training loss: 854.047, validation loss: 846.828
# Epoch:   28, Step:  8400, training loss: 853.875, validation loss: 847.784
# Epoch:   29, Step:  8700, training loss: 851.173, validation loss: 843.787
# Epoch:   30, Step:  9000, training loss: 851.215, validation loss: 838.872
# Epoch:   31, Step:  9300, training loss: 852.093, validation loss: 841.744
# Epoch:   32, Step:  9600, training loss: 851.207, validation loss: 840.331
# Epoch:   33, Step:  9900, training loss: 851.290, validation loss: 843.929
# Epoch:   34, Step: 10200, training loss: 852.765, validation loss: 847.633
# Epoch:   35, Step: 10500, training loss: 851.490, validation loss: 839.803
# Epoch:   36, Step: 10800, training loss: 851.183, validation loss: 842.568
# Epoch:   37, Step: 11100, training loss: 852.115, validation loss: 839.230
# Epoch:   38, Step: 11400, training loss: 852.554, validation loss: 846.994
# Epoch:   39, Step: 11700, training loss: 848.831, validation loss: 836.276
# Epoch:   40, Step: 12000, training loss: 851.137, validation loss: 837.359
# Epoch:   41, Step: 12300, training loss: 848.629, validation loss: 840.059
# Epoch:   42, Step: 12600, training loss: 851.628, validation loss: 837.159
# Epoch:   43, Step: 12900, training loss: 851.277, validation loss: 842.306
# Epoch:   44, Step: 13200, training loss: 846.763, validation loss: 833.792
# Epoch:   45, Step: 13500, training loss: 846.884, validation loss: 836.647
# Epoch:   46, Step: 13800, training loss: 846.687, validation loss: 835.603
# Epoch:   47, Step: 14100, training loss: 846.454, validation loss: 835.852
# Epoch:   48, Step: 14400, training loss: 846.442, validation loss: 836.827
# Epoch:   49, Step: 14700, training loss: 848.099, validation loss: 836.609
# Epoch:   50, Step: 15000, training loss: 843.518, validation loss: 841.573
# Epoch:   51, Step: 15300, training loss: 845.841, validation loss: 837.304
# Epoch:   52, Step: 15600, training loss: 845.667, validation loss: 835.607
# Epoch:   53, Step: 15900, training loss: 845.476, validation loss: 832.431
# Epoch:   54, Step: 16200, training loss: 846.514, validation loss: 835.659
# Epoch:   55, Step: 16500, training loss: 844.527, validation loss: 834.140
# Epoch:   56, Step: 16800, training loss: 843.200, validation loss: 837.351
# Epoch:   57, Step: 17100, training loss: 844.599, validation loss: 833.249
# Epoch:   58, Step: 17400, training loss: 843.900, validation loss: 837.500
# Epoch:   59, Step: 17700, training loss: 844.197, validation loss: 838.236
# Epoch:   60, Step: 18000, training loss: 847.806, validation loss: 836.518
# Learning rate decreased to 0.00950000
# Epoch:   61, Step: 18300, training loss: 842.971, validation loss: 835.798
# Epoch:   62, Step: 18600, training loss: 844.133, validation loss: 831.852
# Epoch:   63, Step: 18900, training loss: 842.453, validation loss: 833.232
# Epoch:   64, Step: 19200, training loss: 840.402, validation loss: 830.834
# Epoch:   65, Step: 19500, training loss: 842.111, validation loss: 831.487
# Epoch:   66, Step: 19800, training loss: 839.737, validation loss: 831.492
# Epoch:   67, Step: 20100, training loss: 844.342, validation loss: 834.534
# Learning rate decreased to 0.00902500
# Epoch:   68, Step: 20400, training loss: 842.962, validation loss: 831.227
# Epoch:   69, Step: 20700, training loss: 844.805, validation loss: 831.526
# Epoch:   70, Step: 21000, training loss: 839.133, validation loss: 828.306
# Epoch:   71, Step: 21300, training loss: 839.338, validation loss: 827.713
# Epoch:   72, Step: 21600, training loss: 838.182, validation loss: 830.360
# Epoch:   73, Step: 21900, training loss: 838.832, validation loss: 832.133
# Epoch:   74, Step: 22200, training loss: 841.093, validation loss: 829.151
# Epoch:   75, Step: 22500, training loss: 843.484, validation loss: 833.447
# Epoch:   76, Step: 22800, training loss: 841.811, validation loss: 830.171
# Epoch:   77, Step: 23100, training loss: 839.750, validation loss: 829.891
# Epoch:   78, Step: 23400, training loss: 839.127, validation loss: 828.680
# Epoch:   79, Step: 23700, training loss: 841.589, validation loss: 834.298
# Epoch:   80, Step: 24000, training loss: 840.878, validation loss: 831.348
# Epoch:   81, Step: 24300, training loss: 842.313, validation loss: 828.813
# Epoch:   82, Step: 24600, training loss: 840.677, validation loss: 833.050
# Epoch:   83, Step: 24900, training loss: 838.548, validation loss: 831.514
# Epoch:   84, Step: 25200, training loss: 839.869, validation loss: 830.253
# Epoch:   85, Step: 25500, training loss: 840.300, validation loss: 830.280
# Epoch:   86, Step: 25800, training loss: 841.556, validation loss: 836.020
# Epoch:   87, Step: 26100, training loss: 841.875, validation loss: 834.511
# Epoch:   88, Step: 26400, training loss: 837.241, validation loss: 832.309
# Epoch:   89, Step: 26700, training loss: 840.447, validation loss: 829.693
# Epoch:   90, Step: 27000, training loss: 839.394, validation loss: 830.390
# Epoch:   91, Step: 27300, training loss: 837.187, validation loss: 827.534
# Epoch:   92, Step: 27600, training loss: 838.691, validation loss: 831.489
# Epoch:   93, Step: 27900, training loss: 836.245, validation loss: 828.786
# Epoch:   94, Step: 28200, training loss: 839.541, validation loss: 828.035
# Epoch:   95, Step: 28500, training loss: 838.467, validation loss: 832.346
# Epoch:   96, Step: 28800, training loss: 835.834, validation loss: 833.129
# Epoch:   97, Step: 29100, training loss: 840.469, validation loss: 830.198
# Learning rate decreased to 0.00857375
# Epoch:   98, Step: 29400, training loss: 836.045, validation loss: 828.284
# Epoch:   99, Step: 29700, training loss: 835.757, validation loss: 826.652
# Epoch:  100, Step: 30000, training loss: 837.892, validation loss: 825.108
# Epoch:  101, Step: 30300, training loss: 837.469, validation loss: 831.103
# Epoch:  102, Step: 30600, training loss: 837.708, validation loss: 831.882
# Epoch:  103, Step: 30900, training loss: 840.572, validation loss: 829.985
# Learning rate decreased to 0.00814506
# Epoch:  104, Step: 31200, training loss: 837.899, validation loss: 826.105
# Epoch:  105, Step: 31500, training loss: 836.007, validation loss: 833.691
# Epoch:  106, Step: 31800, training loss: 837.962, validation loss: 827.248
# Epoch:  107, Step: 32100, training loss: 835.200, validation loss: 829.037
# Epoch:  108, Step: 32400, training loss: 836.226, validation loss: 830.700
# Epoch:  109, Step: 32700, training loss: 839.883, validation loss: 828.681
# Epoch:  110, Step: 33000, training loss: 836.545, validation loss: 827.835
# Epoch:  111, Step: 33300, training loss: 835.877, validation loss: 832.676
# Epoch:  112, Step: 33600, training loss: 835.216, validation loss: 828.871
# Epoch:  113, Step: 33900, training loss: 834.266, validation loss: 828.695
# Epoch:  114, Step: 34200, training loss: 835.410, validation loss: 826.517
# Epoch:  115, Step: 34500, training loss: 837.749, validation loss: 829.688
# Epoch:  116, Step: 34800, training loss: 836.197, validation loss: 831.724
# Epoch:  117, Step: 35100, training loss: 835.724, validation loss: 826.551
# Epoch:  118, Step: 35400, training loss: 836.695, validation loss: 829.493
# Epoch:  119, Step: 35700, training loss: 838.507, validation loss: 826.660
# Learning rate decreased to 0.00773781
# Epoch:  120, Step: 36000, training loss: 836.439, validation loss: 827.022
# Epoch:  121, Step: 36300, training loss: 834.700, validation loss: 830.761
# Epoch:  122, Step: 36600, training loss: 838.698, validation loss: 828.421
# Epoch:  123, Step: 36900, training loss: 837.825, validation loss: 823.887
# Epoch:  124, Step: 37200, training loss: 834.432, validation loss: 824.716
# Epoch:  125, Step: 37500, training loss: 835.757, validation loss: 824.737
# Epoch:  126, Step: 37800, training loss: 834.182, validation loss: 828.147
# Epoch:  127, Step: 38100, training loss: 835.691, validation loss: 823.440
# Epoch:  128, Step: 38400, training loss: 836.177, validation loss: 827.370
# Epoch:  129, Step: 38700, training loss: 834.630, validation loss: 826.323
# Epoch:  130, Step: 39000, training loss: 831.503, validation loss: 826.887
# Epoch:  131, Step: 39300, training loss: 834.697, validation loss: 828.273
# Epoch:  132, Step: 39600, training loss: 833.677, validation loss: 825.345
# Epoch:  133, Step: 39900, training loss: 837.140, validation loss: 824.967
# Learning rate decreased to 0.00735092
# Epoch:  134, Step: 40200, training loss: 835.912, validation loss: 824.472
# Epoch:  135, Step: 40500, training loss: 834.046, validation loss: 822.304
# Epoch:  136, Step: 40800, training loss: 832.797, validation loss: 827.010
# Epoch:  137, Step: 41100, training loss: 833.936, validation loss: 825.653
# Epoch:  138, Step: 41400, training loss: 833.535, validation loss: 823.506
# Epoch:  139, Step: 41700, training loss: 832.670, validation loss: 822.726
# Epoch:  140, Step: 42000, training loss: 834.864, validation loss: 822.876
# Epoch:  141, Step: 42300, training loss: 836.579, validation loss: 824.410
# Learning rate decreased to 0.00698337
# Epoch:  142, Step: 42600, training loss: 831.866, validation loss: 824.818
# Epoch:  143, Step: 42900, training loss: 833.020, validation loss: 822.805
# Epoch:  144, Step: 43200, training loss: 831.250, validation loss: 822.732
# Epoch:  145, Step: 43500, training loss: 834.319, validation loss: 821.511
# Epoch:  146, Step: 43800, training loss: 833.226, validation loss: 824.202
# Epoch:  147, Step: 44100, training loss: 833.689, validation loss: 825.956
# Epoch:  148, Step: 44400, training loss: 833.798, validation loss: 823.970
# Epoch:  149, Step: 44700, training loss: 832.747, validation loss: 824.492
# Epoch:  150, Step: 45000, training loss: 833.047, validation loss: 823.904
# ...training complete.

# %% [markdown]
# ## Load checkpoint with lowest validation error

# %%
model.load_checkpoint('best')

# %% [markdown]
# ## Plot results summary

# %%
print(output_valid.shape)
#model.plot_factors()
tt = np.zeros((all_time,2))
gg = int(NRep/batch_size)
for k in range(gg):
    t = model.infer_factors(output_valid[batch_size *k:batch_size *(k+1),:])
    #print(t)
    for i in range(batch_size):
        for j in range(Time):
            tt[(i+batch_size*k)*Time+j,:]=t[i][j].to('cpu').detach().numpy().copy()
plt.figure()
plt.plot(tt)
# Out:
# torch.Size([300, 10, 85])
# [<matplotlib.lines.Line2D at 0x1a6be49d630>,
#  <matplotlib.lines.Line2D at 0x1a6be49d780>]

# %%
import funs
qz_mean_est = tt
#plt.plot(qz_mean_est[:,0])
qz_est_norm = qz_mean_est#np.stack(qz_mean_est)/np.linalg.norm(np.stack(qz_mean_est))
#plt.plot(qz_est_norm[:,0],qz_est_norm[:,1])
z_true_c = traj# - x_test.mean(axis=0)
z_true_norm = z_true_c#/np.linalg.norm(z_true_c)

R = funs.compute_optimal_rotation(np.stack(qz_est_norm), z_true_norm, scale=True)
qz_est_norm_R = np.stack(qz_est_norm).dot(R)

from scipy import signal
qz_est_norm_R[:,0] = signal.savgol_filter(qz_est_norm_R[:,0], 51, 5)
qz_est_norm_R[:,1] = signal.savgol_filter(qz_est_norm_R[:,1],51, 5)
plt.figure(figsize=(14,8))
plt.subplot(211)
plt_post = plt.plot(qz_est_norm_R[:,0],'r', linewidth = 3, label = 'posterior mean')
plt_true = plt.plot(z_true_norm[:,0], 'k', linewidth = 3, label = '\"true\" mean')
plt.subplot(212)
plt_post = plt.plot(qz_est_norm_R[:,1],'r', linewidth = 3, label = 'posterior mean')
plt_true = plt.plot(z_true_norm[:,1], 'k', linewidth = 3, label = '\"true\" mean')

fig = plt.figure(figsize=(5,5))
plt.plot(z_true_norm[:,0], z_true_norm[:,1], lw=2, color = 'k')
plt.plot(qz_est_norm_R[:,0], qz_est_norm_R[:,1], lw=2, color = 'r')
